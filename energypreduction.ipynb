# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/Net_generation_for_all_sectors.csv",index_col=0);
data.head()
# Out:
#                                                             units  \
# description
# Net generation for all sectors             thousand megawatthours
# United States                                                 NaN
# United States : all fuels (utility-scale)                     NaN
# United States : other renewables           thousand megawatthours
# United States : wind                       thousand megawatthours
#
#                                                      source key  Jan 2001  \
# description
# Net generation for all sectors                              NaN       NaN
# United States                                       ELEC.GEN..M       NaN
# United States : all fuels (utility-scale)  ELEC.GEN.ALL-US-99.M       NaN
# United States : other renewables           ELEC.GEN.AOR-US-99.M    6025.0
# United States : wind                       ELEC.GEN.WND-US-99.M     389.0
#
#                                            Feb 2001  Mar 2001  Apr 2001  \
# description
# ...

# %%
data.dropna(inplace=True)
data.drop([data.columns[0], data.columns[1]], axis=1, inplace=True)

# %%
#datanew.set_index('description')
data.head()
# Out:
#                                              Jan 2001  Feb 2001  Mar 2001  \
# description
# United States : other renewables               6025.0    5310.0    5795.0
# United States : wind                            389.0     431.0     532.0
# United States : all utility-scale solar           7.0      13.0      31.0
# United States : geothermal                     1229.0    1073.0    1190.0
# United States : wood and wood-derived fuels    3191.0    2697.0    2853.0
#
#                                              Apr 2001  May 2001  Jun 2001  \
# description
# United States : other renewables               5827.0    5738.0    5964.0
# United States : wind                            685.0     635.0     670.0
# United States : all utility-scale solar          39.0      81.0      91.0
# United States : geothermal                     1095.0    1071.0    1088.0
# United States : wood and wood-derived fuels    2821.0    2740.0    2891.0
#
# ...

# %%
data =data.T

# %%
data.columns.tolist()
# Out:
# ['United States : other renewables',
#  'United States : wind',
#  'United States : all utility-scale solar',
#  'United States : geothermal',
#  'United States : wood and wood-derived fuels',
#  'United States : other biomass',
#  'United States : all utility-scale solar']

# %%
data.dtypes
# Out:
# description
# United States : other renewables               float64
# United States : wind                           float64
# United States : all utility-scale solar        float64
# United States : geothermal                     float64
# United States : wood and wood-derived fuels    float64
# United States : other biomass                  float64
# United States : all utility-scale solar        float64
# dtype: object

# %%
data=data.T.drop_duplicates().T
names_colums= ['Other renewables','Wind', 'All utility-scale solar',
               'Geothermal', 'Wood and wood-derived fuels', 'Other biomass']
data.columns =names_colums
data.head()
# Out:
#           Other renewables   Wind  All utility-scale solar  Geothermal  \
# Jan 2001            6025.0  389.0                      7.0      1229.0
# Feb 2001            5310.0  431.0                     13.0      1073.0
# Mar 2001            5795.0  532.0                     31.0      1190.0
# Apr 2001            5827.0  685.0                     39.0      1095.0
# May 2001            5738.0  635.0                     81.0      1071.0
#
#           Wood and wood-derived fuels  Other biomass
# Jan 2001                       3191.0         1209.0
# Feb 2001                       2697.0         1096.0
# Mar 2001                       2853.0         1189.0
# Apr 2001                       2821.0         1187.0
# May 2001                       2740.0         1211.0

# %%
data.index.names = ['Date']
#dataT.columns.names = ['Energy']
data.index = pd.to_datetime(data.index)

# %%
data.plot()
