# %%
from module import tools as tl

# %%
url ='data/Net_generation_for_all_sectors.csv'
denrgt = tl.EnergyPrediction(url)

# %%
denrgt.data.head()
# Out:
#             Other renewables   Wind  All utility-scale solar  Geothermal  \
# Date
# 2001-01-01            6025.0  389.0                      7.0      1229.0
# 2001-02-01            5310.0  431.0                     13.0      1073.0
# 2001-03-01            5795.0  532.0                     31.0      1190.0
# 2001-04-01            5827.0  685.0                     39.0      1095.0
# 2001-05-01            5738.0  635.0                     81.0      1071.0
#
#             Wood and wood-derived fuels  Other biomass
# Date
# 2001-01-01                       3191.0         1209.0
# 2001-02-01                       2697.0         1096.0
# 2001-03-01                       2853.0         1189.0
# 2001-04-01                       2821.0         1187.0
# 2001-05-01                       2740.0         1211.0

# %%
denrgt.showEnergyGen()

# %%
denrgt.showTrendGen(denrgt.data[[denrgt.data.columns[0]]])

# %%
denrgt.promMov(denrgt.data[[denrgt.data.columns[0]]]);

# %%
denrgt.descST(denrgt.data[[denrgt.data.columns[0]]])

# %%
denrgt.adjuARIMA(denrgt.data[[denrgt.data.columns[0]]])
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)

# %%
denrgt.data[[denrgt.data.columns[0]]].head()
# Out:
#             Other renewables
# Date
# 2001-01-01            6025.0
# 2001-02-01            5310.0
# 2001-03-01            5795.0
# 2001-04-01            5827.0
# 2001-05-01            5738.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm 
import datetime
import pmdarima as pm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-337-a0619019203c> in <module>
#       3 import statsmodels.api as sm
#       4 import datetime
# ----> 5 import pmdarima as pm
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
modelo = sm.tsa.ARIMA(denrgt.data[denrgt.data.columns[0]].iloc[:180], order=(4, 1, 5), freq = 'MS')  
resultados = modelo.fit(disp=5)
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:488: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
fc, se, conf = resultados.forecast(25, alpha=0.05)  # 95% conf

# %%
fc_series = pd.Series(fc, index=denrgt.data[denrgt.data.columns[0]].iloc[166:].index)
lower_series = pd.Series(conf[:, 0], index=denrgt.data[denrgt.data.columns[0]].iloc[166:].index)
upper_series = pd.Series(conf[:, 1], index=denrgt.data[denrgt.data.columns[0]].iloc[166:].index)

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(denrgt.data[denrgt.data.columns[0]].iloc[0:], label='training')
plt.plot(denrgt.data[denrgt.data.columns[0]].iloc[:85], label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
